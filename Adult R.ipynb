# %%
data <- read.csv("adult_spread.csv")
print(data)

# %%
df = data[, c("age", "education_num", "capital_gain","capital_loss","hours_per_week","Federal_gov","State_gov","Local_gov","Private", "Total" )]

# %%
pairs(df, labels = colnames(df), main = "Pairs matrix", pch = 21, 
    bg = c("red", "green3", "blue", "yellow")[unclass(df$Day.Calls)], upper.panel = NULL)
# Out:
# plot without title
