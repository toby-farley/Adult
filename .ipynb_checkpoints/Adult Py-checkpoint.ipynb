# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("adult_spread.csv")
df["class"]
# Out:
# 0        <=50K
# 1        <=50K
# 2         >50K
# 3         >50K
# 4        <=50K
#          ...
# 48837    <=50K
# 48838     >50K
# 48839    <=50K
# 48840    <=50K
# 48841     >50K
# Name: class, Length: 48842, dtype: object

# %%
print(df.describe())
# Out:
#                 age        fnlwgt  education_num  capital_gain  capital_loss  \
# count  48842.000000  4.884200e+04   48842.000000  48842.000000  48842.000000
# mean      38.643585  1.896641e+05      10.078089   1079.067626     87.502314
# std       13.710510  1.056040e+05       2.570973   7452.019058    403.004552
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.175505e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.781445e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.376420e+05      12.000000      0.000000      0.000000
# max       90.000000  1.490400e+06      16.000000  99999.000000   4356.000000
#
#        hours_per_week       Private     Local_gov  Self_emp_not_inc  \
# count    48842.000000  48842.000000  48842.000000      48842.000000
# mean        40.422382   1777.358912    162.249662        184.489067
# std         12.391444   1660.576345    704.811992        735.711643
# ...

# %%
print(df[["age","fnlwgt" ,"education_num", "capital_gain", "capital_loss"]].var(skipna=True, numeric_only=True))
# Out:
# age              1.879781e+02
# fnlwgt           1.115221e+10
# education_num    6.609901e+00
# capital_gain     5.553259e+07
# capital_loss     1.624127e+05
# dtype: float64

# %%
private_df = df[df['workclass'] == 'Private']

# %%
private_workers = private_df[["Preschool","1st_4th","5th_6th","7th_8th","10th","11th","12th","HS_grad","Assoc_voc","Prof_school","Some_college","Assoc_acdm","Bachelors","Masters","Doctorate"]].sum()

# %%
fig = plt.figure(figsize = (10, 5))

# creating the bar plot
private_workers.plot.bar()

plt.title("Plot Education in Private Employment")
plt.xlabel("Education Level")
plt.ylabel("Total Individuals")

plt.show()

# %%
all_workers = df[["Preschool","1st_4th","5th_6th","7th_8th","10th","11th","12th","HS_grad","Assoc_voc","Prof_school","Some_college","Assoc_acdm","Bachelors","Masters","Doctorate"]].sum()

# %%
all_workers
# Out:
# Preschool         280669
# 1st_4th           821541
# 5th_6th          1655782
# 7th_8th          2535324
# 10th             3863318
# 11th             5003156
# 12th             1836708
# HS_grad         42135098
# Assoc_voc        5233301
# Prof_school      2202261
# Some_college    29250785
# Assoc_acdm       4388796
# Bachelors       21392530
# Masters          6824102
# Doctorate        1547545
# dtype: int64

# %%
fig = plt.figure(figsize = (10, 5))

# creating the bar plot
all_workers.plot.bar()

plt.title("Plot Education in All Employment")
plt.xlabel("Education Level")
plt.ylabel("Total Individuals")

plt.show()

# %%
Federal_gov_df = df[df['class'] == '>50K'][["Preschool","1st_4th","5th_6th","7th_8th","10th","11th","12th","HS_grad","Assoc_voc","Prof_school","Some_college","Assoc_acdm","Bachelors","Masters","Doctorate"]].sum()

# %%
#Federal_gov_workers = Federal_gov_df[["Preschool","1st_4th","5th_6th","7th_8th","10th","11th","12th","HS_grad","Assoc_voc","Prof_school","Some_college","Assoc_acdm","Bachelors","Masters","Doctorate"]].sum()
print(Federal_gov_df)
# Out:
# Preschool          2589
# 1st_4th           19959
# 5th_6th           60376
# 7th_8th          144679
# 10th             228524
# 11th             213226
# 12th             133932
# HS_grad         6128508
# Assoc_voc       1262906
# Prof_school     1525425
# Some_college    5322044
# Assoc_acdm      1078775
# Bachelors       8383817
# Masters         3603457
# Doctorate       1069139
# dtype: int64

# %%
fig = plt.figure(figsize = (10, 5))

# creating the bar plot
Federal_gov_workers.plot.bar()

plt.title("Plot of Education in Government Employment")
plt.xlabel("Education Level")
plt.ylabel("Total Individuals")

plt.show()

# %%
plt.figure(figsize=(6,20))
sumed = df.groupby(['workclass','education'], sort=True)["Total"].sum("Total")/10000
unstacked = sumed.unstack(level=0)
sns.heatmap(unstacked, annot=True, fmt=".1f")
plt.title("Worker class by Education (In 10000s)")
plt.xlabel("workclass")
plt.ylabel("education")
plt.show()
# Out:
# workclass    education
# Federal-gov  10th              2.4306
#              11th              3.0875
#              12th              2.2125
#              1st-4th           0.4444
#              5th-6th           0.2732
#                                ...
# State-gov    Some-college    121.8240
# Without-pay  7th-8th           0.3229
#              Assoc-acdm        0.3922
#              HS-grad           3.2435
#              Some-college      0.7271
# Name: Total, Length: 103, dtype: float64

# %%
sumed = df.groupby(['workclass','education'], sort=True)["Total"].sum("Total")/10000

# %%
sumed = df.groupby(['education_num','class'], sort=True)["Total"].sum("Total")/10000

# %%
sns.color_palette("Spectral", as_cmap=True)
sns.catplot(x="education_num", y="Total", hue="class", data=df)
plt.tight_layout()

# %%
sns.color_palette("Spectral", as_cmap=True)
sns.catplot(x="sex", y="Total", hue="class", data=df)
plt.tight_layout()

# %%
df[["education_num","workclass","class", "Total"]]
# Out:
#        education_num     workclass  class  Total
# 0                  7       Private  <=50K   3014
# 1                  9       Private  <=50K   1194
# 2                 12     Local-gov   >50K   4478
# 3                 10       Private   >50K   2130
# 4                 10           NaN  <=50K   1375
# ...              ...           ...    ...    ...
# 48837             12       Private  <=50K   3419
# 48838              9       Private   >50K   2051
# 48839              9       Private  <=50K   2019
# 48840              9       Private  <=50K   2678
# 48841              9  Self-emp-inc   >50K   3826
#
# [48842 rows x 4 columns]

# %%
df.groupby(["education_num","workclass","class"])['Total'].sum().reset_index()
# Out:
#      education_num         workclass  class   Total
# 0                1         Local-gov  <=50K    9133
# 1                1           Private  <=50K  198414
# 2                1           Private   >50K    2589
# 3                1  Self-emp-not-inc  <=50K   15233
# 4                1         State-gov  <=50K    1032
# ..             ...               ...    ...     ...
# 180             16      Self-emp-inc   >50K  115555
# 181             16  Self-emp-not-inc  <=50K   55948
# 182             16  Self-emp-not-inc   >50K  121598
# 183             16         State-gov  <=50K   61610
# 184             16         State-gov   >50K  235448
#
# [185 rows x 4 columns]
